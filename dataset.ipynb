# %% [markdown]
# <a href="https://colab.research.google.com/github/AliArshad20/Flutter-monthlycourse/blob/main/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=../content/drive/MyDrive/datasets/theft/data.yaml epochs=100 batch=4 imgsz=320 amp=True workers=8
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 61.0MB/s]
# Ultralytics 8.3.81 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
